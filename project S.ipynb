# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Notes:
#
# SQL for database (heroku)
#
# upload orders - email to warehouse, send to inventory and sales for reports.
#
# SQL Schema - all orders, inventory

# %%
class orders:
    def __init__(self, orders):
        self.orders = orders 
        
        # upload to dbase 
        self.df['date']
        slef.df['sku']
        self.df['qty']
        self.df['name']
        self.df['address_1']
        self.df['address_2']
        self.df['city']
        self.df['state']
        self.df['country']
        self.df['phone']
        self.df['record_id']
        self.df['username']
        self.df['email']
        self.df['saleprice']
        self.df['tracking'] # upload later
        
        # send to sql db
        # send order to warehouse (email)
    
    def pull_data(self):
        # simple queries 
        # able to download csv
        pass
    
    def add_tracking(self):
        # matching orders to tracking 
        # email cs 
        pass


    def inventory(self):
        # displaying inventory 
        
        self.df['sku']
        self.df['total_qty']
        self.df['warehouse']
        
        # subtract/add inventory
        
        # alerts base on metrics, email
        
        # customize alerts 
        pass
    
    
    def daily_reports(self):
        # generate daily reports 
        # channel
        
        # count 
        
        # email 
        
        self.df['date']
        slef.df['sku']
        self.df['qty']
        # daily
        # weekly
        # monthly
        # sku
        # prices
        
        # charts?
        # revenue
        pass
    
    def other_reports(self):
        
        # create customize dashbaords and other reports 
        # dates range 
        
        # find some trends
